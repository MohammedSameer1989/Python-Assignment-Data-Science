# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %%
To calculate the Pearson correlation coefficient (often denoted as 
�
r) between two variables, you can use the following formula:

�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(X 
i
​
 − 
X
ˉ
 ) 
2
 ∑(Y 
i
​
 − 
Y
ˉ
 ) 
2
 
​
 
∑(X 
i
​
 − 
X
ˉ
 )(Y 
i
​
 − 
Y
ˉ
 )
​
 

Where:

�
�
X 
i
​
  and 
�
�
Y 
i
​
  are the individual data points.
�
ˉ
X
ˉ
  and 
�
ˉ
Y
ˉ
  are the means of the variables X and Y, respectively.
The Pearson correlation coefficient ranges from -1 to 1, where:

�
=
1
r=1 indicates a perfect positive linear relationship,
�
=
−
1
r=−1 indicates a perfect negative linear relationship,
�
=
0
r=0 indicates no linear relationship.
Interpretation:

If 
�
>
0
r>0, it suggests a positive linear relationship, meaning as one variable increases, the other tends to increase.
If 
�
<
0
r<0, it suggests a negative linear relationship, meaning as one variable increases, the other tends to decrease.
The magnitude of 
�
r indicates the strength of the linear relationship. Closer to 1 or -1 indicates a stronger relationship, while closer to 0 indicates a weaker relationship.
For example, if the calculated Pearson correlation coefficient between the time spent studying and final exam scores is 0.8, you could interpret it as a strong positive linear relationship, suggesting that students who spend more time studying tend to have higher final exam scores. If 
�
=
−
0.6
r=−0.6, it would indicate a moderate negative linear relationship, suggesting that as study time increases, final exam scores tend to decrease.

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.

# %%
Spearman's rank correlation (
�
ρ) assesses the strength and direction of monotonic relationships between two variables. Monotonic relationships are those where the variables tend to move in the same relative direction, but not necessarily at a constant rate. Unlike Pearson correlation, Spearman's rank correlation does not assume linearity.

To calculate Spearman's rank correlation:

Rank the data for both variables separately.
Calculate the differences between the ranks for each pair of data points.
Square these differences.
Sum the squared differences.
Use the formula:
�
=
1
−
6
∑
�
�
2
�
(
�
2
−
1
)
ρ=1− 
n(n 
2
 −1)
6∑d 
i
2
​
 
​
 

Where:

�
�
d 
i
​
  is the difference between the ranks for each pair of data points.
�
n is the number of data points.
The value of 
�
ρ ranges from -1 to 1, where:

�
=
1
ρ=1 indicates a perfect monotonic increasing relationship.
�
=
−
1
ρ=−1 indicates a perfect monotonic decreasing relationship.
�
=
0
ρ=0 indicates no monotonic relationship.
Interpretation:

A positive 
�
ρ suggests that as one variable increases, the other tends to increase.
A negative 
�
ρ suggests that as one variable increases, the other tends to decrease.
The magnitude of 
�
ρ indicates the strength of the monotonic relationship.
For example, if the calculated Spearman's rank correlation between the amount of sleep and job satisfaction is 0.75, you could interpret it as a strong positive monotonic relationship. This suggests that individuals who get more sleep tend to report higher job satisfaction levels on the scale of 1 to 10.

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.

# %%
To calculate the Pearson correlation coefficient (
�
r) and Spearman's rank correlation (
�
ρ), you would follow these steps:

Assuming you have the data for the number of hours of exercise per week (
�
X) and the body mass index (BMI) (
�
Y) for 50 participants, and the data is denoted as 
(
�
1
,
�
1
)
,
(
�
2
,
�
2
)
,
…
,
(
�
50
,
�
50
)
(X 
1
​
 ,Y 
1
​
 ),(X 
2
​
 ,Y 
2
​
 ),…,(X 
50
​
 ,Y 
50
​
 ).

Pearson Correlation Coefficient (
�
r):
Calculate the means (
�
ˉ
X
ˉ
  and 
�
ˉ
Y
ˉ
 ):
�
ˉ
=
∑
�
�
�
X
ˉ
 = 
n
∑X 
i
​
 
​
 
�
ˉ
=
∑
�
�
�
Y
ˉ
 = 
n
∑Y 
i
​
 
​
 

Calculate the Pearson correlation coefficient (
�
r):
�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(X 
i
​
 − 
X
ˉ
 ) 
2
 ∑(Y 
i
​
 − 
Y
ˉ
 ) 
2
 
​
 
∑(X 
i
​
 − 
X
ˉ
 )(Y 
i
​
 − 
Y
ˉ
 )
​
 

Spearman's Rank Correlation (
�
ρ):
Rank the data:

Assign ranks to the values of 
�
X and 
�
Y separately.
Calculate the differences between ranks (
�
�
d 
i
​
 ):

For each pair 
(
�
�
,
�
�
)
(X 
i
​
 ,Y 
i
​
 ), calculate 
�
�
=
Rank
(
�
�
)
−
Rank
(
�
�
)
d 
i
​
 =Rank(X 
i
​
 )−Rank(Y 
i
​
 ).
Calculate Spearman's rank correlation (
�
ρ):
�
=
1
−
6
∑
�
�
2
�
(
�
2
−
1
)
ρ=1− 
n(n 
2
 −1)
6∑d 
i
2
​
 
​
 

Interpretation:
If 
�
r is close to 1, it suggests a strong positive linear relationship.

If 
�
r is close to -1, it suggests a strong negative linear relationship.

If 
�
r is close to 0, it suggests a weak or no linear relationship.

If 
�
ρ is close to 1, it suggests a strong positive monotonic relationship.

If 
�
ρ is close to -1, it suggests a strong negative monotonic relationship.

If 
�
ρ is close to 0, it suggests a weak or no monotonic relationship.

Comparison:
�
r measures linear relationships.
�
ρ measures monotonic relationships without assuming linearity.
You might observe that 
�
r and 
�
ρ can provide different insights into the nature of the relationship between the number of hours of exercise per week and BMI, depending on the distribution and patterns in your data.

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.

# %%
To calculate the Pearson correlation coefficient (
�
r), you would follow these steps:

Assuming you have the data for the number of hours individuals spend watching television per day (
�
X) and their level of physical activity (
�
Y) for 50 participants, and the data is denoted as 
(
�
1
,
�
1
)
,
(
�
2
,
�
2
)
,
…
,
(
�
50
,
�
50
)
(X 
1
​
 ,Y 
1
​
 ),(X 
2
​
 ,Y 
2
​
 ),…,(X 
50
​
 ,Y 
50
​
 ).

Calculate the means (
�
ˉ
X
ˉ
  and 
�
ˉ
Y
ˉ
 ):
�
ˉ
=
∑
�
�
�
X
ˉ
 = 
n
∑X 
i
​
 
​
 
�
ˉ
=
∑
�
�
�
Y
ˉ
 = 
n
∑Y 
i
​
 
​
 

Calculate the Pearson correlation coefficient (
�
r):
�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(X 
i
​
 − 
X
ˉ
 ) 
2
 ∑(Y 
i
​
 − 
Y
ˉ
 ) 
2
 
​
 
∑(X 
i
​
 − 
X
ˉ
 )(Y 
i
​
 − 
Y
ˉ
 )
​
 

Here, 
�
n is the number of participants, 
�
�
X 
i
​
  and 
�
�
Y 
i
​
  are the individual data points, and 
�
ˉ
X
ˉ
  and 
�
ˉ
Y
ˉ
  are the means.

Interpretation of 
�
r:

If 
�
>
0
r>0, it suggests a positive linear relationship, meaning as the number of hours watching TV increases, physical activity tends to increase.
If 
�
<
0
r<0, it suggests a negative linear relationship, meaning as the number of hours watching TV increases, physical activity tends to decrease.
The magnitude of 
�
r indicates the strength of the linear relationship. Closer to 1 or -1 indicates a stronger relationship, while closer to 0 indicates a weaker relationship.
Keep in mind that correlation does not imply causation, and additional analysis or experimental design may be needed to draw causal conclusions.

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %%
To calculate the Pearson correlation coefficient (
�
r), you would follow these steps:

Assuming you have the data for the number of sales calls made per day (
�
X) and the number of sales made per week (
�
Y) for 30 sales representatives, and the data is denoted as 
(
�
1
,
�
1
)
,
(
�
2
,
�
2
)
,
…
,
(
�
30
,
�
30
)
(X 
1
​
 ,Y 
1
​
 ),(X 
2
​
 ,Y 
2
​
 ),…,(X 
30
​
 ,Y 
30
​
 ).

Calculate the means (
�
ˉ
X
ˉ
  and 
�
ˉ
Y
ˉ
 ):
�
ˉ
=
∑
�
�
�
X
ˉ
 = 
n
∑X 
i
​
 
​
 
�
ˉ
=
∑
�
�
�
Y
ˉ
 = 
n
∑Y 
i
​
 
​
 

Calculate the Pearson correlation coefficient (
�
r):
�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(X 
i
​
 − 
X
ˉ
 ) 
2
 ∑(Y 
i
​
 − 
Y
ˉ
 ) 
2
 
​
 
∑(X 
i
​
 − 
X
ˉ
 )(Y 
i
​
 − 
Y
ˉ
 )
​
 

Here, 
�
n is the number of sales representatives, 
�
�
X 
i
​
  and 
�
�
Y 
i
​
  are the individual data points, and 
�
ˉ
X
ˉ
  and 
�
ˉ
Y
ˉ
  are the means.

Interpretation of 
�
r:

If 
�
>
0
r>0, it suggests a positive linear relationship, meaning as the number of sales calls made per day increases, the number of sales made per week tends to increase.
If 
�
<
0
r<0, it suggests a negative linear relationship, meaning as the number of sales calls made per day increases, the number of sales made per week tends to decrease.
The magnitude of 
�
r indicates the strength of the linear relationship. Closer to 1 or -1 indicates a stronger relationship, while closer to 0 indicates a weaker relationship.
Remember that correlation does not imply causation, and additional analysis or experimental design may be needed to draw causal conclusions.

# %% [markdown]
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:
# Age(Years)
# 25 Coke
# 42 Pepsi
# 37
# 19
# 31
# 28
# Mountain dew
# Coke
# Pepsi
# Coke
# Soft drink Preference

# %%
It seems like the data you provided includes a list of ages (in years) and the corresponding soft drink preferences for each individual. To analyze the relationship between age and soft drink preference, you might want to use statistical methods such as creating a frequency distribution or calculating measures of central tendency. However, keep in mind that the nature of your data is categorical (soft drink preference) and numerical (age), and therefore, certain statistical measures may be more appropriate than others.

If you're interested in a broad overview, you can create a frequency distribution for the soft drink preferences and explore the central tendency of age. Here's a simple example:

Soft Drink Preference:

Coke: 3 individuals
Pepsi: 2 individuals
Mountain Dew: 1 individual
For the ages:

Mean (average) age: 
(
25
+
42
+
37
+
19
+
31
+
28
)
/
6
=
mean age
(25+42+37+19+31+28)/6=mean age
Median (middle value): arrange the ages in ascending order and find the middle value.
However, if you want to examine the relationship between age and soft drink preference more rigorously, you may need additional data and conduct more advanced statistical analyses, such as chi-square tests for independence or logistic regression if the soft drink preference is binary.

It's important to note that with the limited data provided, a comprehensive analysis may not be possible. If you have more data or specific analysis goals, please provide additional information so that I can assist you more effectively.
